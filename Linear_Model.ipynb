# %% [markdown]
# <a href="https://colab.research.google.com/github/osctoss/Linear_regression_model/blob/main/Linear_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Import Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# **2. Creating random dataset**

# %%
X = np.random.rand(20).reshape(-1,1)
Y = np.random.rand(20)

print("X = ", X)
print("\nY = ", Y)
# Out:
# X =  [[0.74010562]
#  [0.66352118]
#  [0.36022017]
#  [0.87172711]
#  [0.58275838]
#  [0.48441483]
#  [0.37739309]
#  [0.76875427]
#  [0.04481035]
#  [0.25852926]
#  [0.31327146]
#  [0.31465745]
#  [0.49939051]
#  [0.9317907 ]
#  [0.68091444]
#  [0.61422236]
#  [0.11872409]
#  [0.72013498]
#  [0.36978349]
#  [0.97234591]]
#
# Y =  [0.71688671 0.85626039 0.9933093  0.14244695 0.71736137 0.54963147
#  0.18621644 0.33011956 0.05533174 0.33189732 0.65377707 0.09645853
#  0.69392002 0.36307385 0.89717581 0.92435909 0.40443832 0.99918981
#  0.77089045 0.79950048]

# %% [markdown]
# **3. Splitting data into train and test dataset**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 20 )

print("X_train",X_train)

print("\nX_test",X_test)

print("\nY_train",Y_train)

print("\nY_test",Y_test)
# Out:
# X_train [[0.72013498]
#  [0.49939051]
#  [0.97234591]
#  [0.48441483]
#  [0.04481035]
#  [0.36978349]
#  [0.74010562]
#  [0.36022017]
#  [0.76875427]
#  [0.37739309]
#  [0.31465745]
#  [0.25852926]
#  [0.61422236]
#  [0.87172711]]
#
# X_test [[0.11872409]
#  [0.9317907 ]
#  [0.31327146]
#  [0.58275838]
#  [0.66352118]
#  [0.68091444]]
#
# Y_train [0.99918981 0.69392002 0.79950048 0.54963147 0.05533174 0.77089045
#  0.71688671 0.9933093  0.33011956 0.18621644 0.09645853 0.33189732
#  0.92435909 0.14244695]
#
# Y_test [0.40443832 0.36307385 0.65377707 0.71736137 0.85626039 0.89717581]

# %% [markdown]
# **4. Creating an instance for the linear regression model**

# %%
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %% [markdown]
# **5. Creating/Train Linear Model**

# %%
# Training the model by passing the dependent and independent features of the training dataset
lr.fit(X_train, Y_train)
lr
# Out:
# LinearRegression()

# %% [markdown]
# **6. Make prediction on test dataset**

# %%
Y_pred = lr.predict( X_test)

print(Y_pred)
# Out:
# [0.35513776 0.7263732  0.44396551 0.56700967 0.6038849  0.61182642]

# %% [markdown]
# **7. Model Evaluation**

# %% [markdown]
# **7.1 Get the coefficients**

# %%
# The value of the coefficients for the independent feature through the multiple regression model
print("Value of the oefficients: \n", lr.coef_)
# Out:
# Value of the oefficients:
#  [0.45658675]

# %% [markdown]
# **7.2 Get Mean squared error between Actual and Predicted**

# %%
# The value of the mean squared error
print(f"Mean square error: {mean_squared_error( Y_test, Y_pred)}")
# Out:
# Mean square error: 0.05769352491361581

# %% [markdown]
# **7.3 Get R Square between Actual and Predicted**

# %%
# The value of the coefficient of determination, i.e., R-square score of the model
print(f"Coefficient of determination: {r2_score( Y_test, Y_pred )}")
# Out:
# Coefficient of determination: -0.38018514397765424

# %% [markdown]
# **7.4 Scatter Plot**

# %%
# Plotting the output
plt.scatter(X_test, Y_test, color = "black", label = "original data")
plt.plot(X_test, Y_pred, color = "blue", linewidth=3, label = "regression line")
plt.xlabel("Independent Feature")
plt.ylabel("Target Values")
plt.title("Simple Linear Regression")
plt.show()
